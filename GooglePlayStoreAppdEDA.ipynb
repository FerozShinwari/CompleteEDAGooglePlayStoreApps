# %% [markdown]
# <a href="https://www.kaggle.com/code/ferozshahshinwari/notebook186600838e?scriptVersionId=203855310" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong>Google Play Store Apps EDA</strong></p>

# %% [markdown]
# ## Complete EDA Analysis from Beginner Perspective

# %% [markdown]
# ![Google Play Store Logo](googlelogo.jpg)

# %% [markdown]
# > ####  Let us Understand Step By Step How to Explore Data in Python from a beginner Perspective

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong>1.0 : About Author</strong></p>
#  **`Name`** : Feroz Shinwari
#
#  **`Code Submission Date`** : 16-10-2024
#
#  **`Github`**:[https://wwww.github.com/FerozShinwari]
#
# **`Email`** :[https://www.imferoz265@gmail.com]
#
#  **`Linkedin`**:[https://linkedin.com/in/ferozshinwari]
#
#
#  **`Twitter`**:[https://twitter.com/@ImFerozShinwari]

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong>1.1: About Data</strong></p>
#
# >**`Name`** :Google Play Store Apps Data
#
# >**`Source`** : [link](https://www.kaggle.com/datasets/lava18/google-play-store-apps)

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong>1.2: Meta Data</strong></p>
# The data set has the following columns in it.
# >**`App`** :The name of the application.
#
# >**`Category`** : The primary category to which the app belongs (e.g., Games, Productivity, Health & Fitness).
#
# >**`Rating`** : The average user rating given to the app on a scale of 0 to 5.
#
#
# >**`Reviews`** : The total number of user reviews for the app.
#
# >**`Size`**: The approximate size of the app in megabytes (MB).
#
# >**`Installs`** : The estimated number of times the app has been downloaded from the Play Store.
#
# >**`Type`**: Whether the app is free or paid.
#
# >**`Price`**: The price of the app in US dollars (only applicable for paid apps).
#
# >**`Content Rating`**: The age suitability rating for the app (e.g., Everyone, Everyone 10+, Teen, Mature 17+).
#
# >**`Genres`**: A list of genres associated with the app.
#
# >**`Last Updated`**: The date when the app was last updated on the Play Store.
#
# >**`Current Ver`**: The current version number of the app

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong>1.3: Task</strong></p>
# >In this notebook we will attempt to caryy out and Exploratory Data Analysis EDA on Google Play Store Apps Dataset.We will carry out different data wrangling and data cleaning methodologies to find out useful insights out of it.

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong>1.4: Objectives </strong></p> > Our aim is to find out useful results and observations , analyze different pattern and finally answer some of the basic questions related with google plays store apps. Based on Google Play Store App Dataset , Our basic objectives of EDA are as follow:
#
# - Helping develpers in finding Which categories of the Apps on google play store have the mosta installtaions.
# - What are the highly trending apps on google play store.
# - Which category has the most installtions?
# - What are the niches in mobile app that a mobile app develper should avoid to go with.
# - Ratio of installtion between paid apps and free apps.
# - To understand the ratio of free and paid app installation and much more.

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong>1.5: Kernel Version</strong></p>
# - python 3.12.7

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong>2.0: Important Libraries</strong></p>
# - Pandas : for Data analysis
# - Seaborn : for visualzation
# - Numpy : for numerical computation
# - matplotlib : for plots and graphics of the data.

# %%
#for analysis and computing
import pandas as pd
import numpy as np

#for visualiztion 
import seaborn as sns
import matplotlib.pyplot as plt

# #this is for jupyter notebook to show the plot in the notebook itself instead of opening a new window for the plot
# %matplotlib inline

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> 2.1:  Data Loading and Exploring</strong></p>

# %%
#LOADING THE CSV FILE
df=pd.read_csv('./googleplaystore.csv')

# %%
#HAVE A LOOK ON TOP 5 RECORDs OF DATASET.
df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> 2.2: Important Things after Loading Dataset</strong></p>

# %%
# Set the maximum level for rows and columns to see all the rows and columns of the dataset.
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#hide all warning
import warnings
warnings.filterwarnings('ignore')

#see columns details  using df.columns
print(f'The names of all the columns in this dataset are, {df.columns}')
# Out:
# The names of all the columns in this dataset are, Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#
#        'Android Ver'],
#
#       dtype='object')

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> 2.3: Shape of the Dataset</strong></p>

# %%
#rows and columns both details   using df.shape function
print(f'The number of rows in this data set is', {df.shape[0]})
print(f'The number of columns in this dataset is',{df.shape[1]})
# Out:
# The number of rows in this data set is {10841}
#
# The number of columns in this dataset is {13}

# %%
#lets Explore it a bit more, like How many columns, Rows , Missing entries are in 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 10841 entries, 0 to 10840
#
# Data columns (total 13 columns):
#
#  #   Column          Non-Null Count  Dtype
#
# ---  ------          --------------  -----
#
#  0   App             10841 non-null  object
#
#  1   Category        10840 non-null  object
#
#  2   Rating          9367 non-null   float64
#
#  3   Reviews         10841 non-null  int64
#
#  4   Size            10841 non-null  object
#
#  5   Installs        10841 non-null  object
#
#  6   Type            10840 non-null  object
#
#  7   Price           10841 non-null  object
#
#  8   Content Rating  10841 non-null  object
#
#  9   Genres          10840 non-null  object
#
#  10  Last Updated    10841 non-null  object
#
#  11  Current Ver     10833 non-null  object
#
#  12  Android Ver     10839 non-null  object
#
# dtypes: float64(1), int64(1), object(11)
#
# memory usage: 1.1+ MB

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# ---
#  - Total entries are 10841 , missing values are present.
#  - The columns are of different datatypes
#  -  The columns in the datasets are:
#    - `'App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'`
#
# - size column is numeric, but here it is labled as object.
# Now , its time to see how many numerical columns we have.

# %% [markdown]
# > **Note** : To see a summarize picture of the dataset we try  df.describe() functions.
# > This function just shows the numerical data.

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> 2.4: Data Cleaning (Very Important Step)</strong></p>

# %%
# view statistical summry of numeric columns
df.describe()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084100e+04
# mean      4.191513  4.441119e+05
# std       0.515735  2.927629e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.476800e+04
# max       5.000000  7.815831e+07

# %% [markdown]
# - **`O Wait a Minute`** :
# - Do you really believe that only these two columns above (Rating and Reviews) are numeric???
#   Off course not.
# ***because we have other numeric columns too,  like  `price`, `size` , `rating`, `installs `and others***
#
# But How ???
#      let see

# %%
#lets see other numeric columns
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
#
# - Here we see that `reviews`, `size`, `installs` and  `price`, all are numeric but why it just shows  these two (Rating and Reviews) above.
# - so we need to make these columns into numeric too. lets go ahead.

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> 2.5: Convert 'size' Column into Numeric datatype</strong></p>

# %%
 # lets first explore the size column, 
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
# 15M                    184
# 17M                    160
# 19M                    154
# 26M                    149
# 16M                    149
# 25M                    143
# 20M                    139
# 21M                    138
# 10M                    136
# 24M                    136
# 18M                    133
# 23M                    117
# 22M                    114
# 29M                    103
# 27M                     97
# 28M                     95
# 30M                     84
# 33M                     79
# 3.3M                    77
# 37M                     76
# 35M                     72
# 31M                     70
# 2.9M                    69
# 2.3M                    68
# 2.5M                    68
# 2.8M                    65
# 3.4M                    65
# 32M                     63
# 34M                     63
# ...

# %% [markdown]
# >***NOTE*** that this is the size of application we are dealing with. That's why its given in '`M`' which means '`MegaBytes`' Which is the unit of memory in bytes and similarly '`K`' means '`KB`' a smaller unit of memory in bytes.

# %%
#Lets see the unique values in size column
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
#
# - Have you noticed the above output from the size column, There are three types of observations
#
# > 1. int or float value with `'M'`
#
# > 2. Int or float value with `'K'`
#
# > 3. and a string value of `'varies with devices'`
#
# - lets handle it one by one

# %%
# #Checking for missing values in size col.
df['Size'].isnull().sum()
# Out:
# 0

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
#
# - Zero Output  means there is  no missing value in this column, lets go ahead
# - - varify the number of values and 3 different kind of values.

# %%
#find the value having 'M' in the  size column
df['Size'].loc[df['Size'].str.contains('M')].value_counts().sum()
# Out:
# 8830

# %%
# #find the value having 'k' in them in size col
df['Size'].loc[df['Size'].str.contains('k')].value_counts().sum()
# Out:
# 316

# %%
#find the value having 'sentence Varies with device' in them in size col
df['Size'].loc[df['Size'].str.contains('Varies with device')].value_counts().sum()
# Out:
# 1695

# %%
# #lets add them if it is equal to len(df) just to varify.
316+1695+8830
# Out:
# 10841

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# - We have `8830` values in `M` units means that their size are in 'MBs'.
# - We have `316` values in `k` units means that their size are in'kbs'.
# - We have `1695` value in `Varies with device`
#
# > Let's convert the `M` and `K` units into bytes and then remove the `M` and `K` from the values and convert them into numeric

# %% [markdown]
# - >***Important*** : In order to furthure explore the size column, and visualize its insights we need to convert all the entries in one same unit. Therefore we define the below function to make all the values of size column in on single unit. See the function below Which are complelty explained in comments, Hope you will enjoy it.

# %%
#converting the whole size into bytes first.
#lets define a function for it.
def convert_size(size):    
    if isinstance(size, str):  #isinstance mean inside the size first deals with string
        if 'k'in size:     #defining our string
            return float(size.replace('k',''))*1024     #we ask to replace k with empy space and make it bytes by *1024
        elif 'M' in size:
            return float(size.replace('M', ''))*1024 *1024    #make it floate coz mb values are  continues 
        elif 'Varies with device' in size:   #if this comes ,make it empty
            return np.nan        #return empty box
        return size       #where there is no mb,kb or varies with device make it as it is.

# %%
#now lets apply the above function
df['Size']=df['Size'].apply(convert_size)

# %%
#now lets check the size value for mb, kb and varies with device
df['Size']
# Out:
# 0         19922944.0
# 1         14680064.0
# 2          9122611.2
# 3         26214400.0
# 4          2936012.8
# 5          5872025.6
# 6         19922944.0
# 7         30408704.0
# 8         34603008.0
# 9          3250585.6
# 10        29360128.0
# 11        12582912.0
# 12        20971520.0
# 13        22020096.0
# 14        38797312.0
# 15         2831155.2
# 16         5767168.0
# 17        17825792.0
# 18        40894464.0
# 19        32505856.0
# 20        14680064.0
# 21        12582912.0
# 22         4404019.2
# 23         7340032.0
# 24        24117248.0
# 25         6291456.0
# 26        26214400.0
# 27         6396313.6
# 28         4823449.6
# 29         4404019.2
# 30         9646899.2
# 31         5452595.2
# 32        11534336.0
# 33        11534336.0
# 34         4404019.2
# 35         9646899.2
# 36        25165824.0
# 37               NaN
# 38        11534336.0
# 39         9856614.4
# 40        15728640.0
# 41        10485760.0
# 42               NaN
# ...

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# >  See the above output , all the size entries are been converted into one single unit of bytes.let go ahead and Enjoy it.

# %%
#lets have a look again into the dataset. 
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews        Size     Installs  Type Price Content Rating  \
# 0      159  19922944.0      10,000+  Free     0       Everyone
# 1      967  14680064.0     500,000+  Free     0       Everyone
# 2    87510   9122611.2   5,000,000+  Free     0       Everyone
# 3   215644  26214400.0  50,000,000+  Free     0           Teen
# 4      967   2936012.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# >***Attention Please*** : Look at the size column above for just 10 seconds, What do you Notice ???
# - Any point ????
# - See agian ???
# - Oh lets try final ??
#
#   **Okey** lemme tell you, Its not that important but still very good if you change it.
#   Do you think it will be more catchy if we change the column name from 'size' to 'size in bytes', isnt it?
#
#   Are you ready ????
#   lets do it.

# %%
# #lets rename  the name of this column from 'Size' to 'Size_in_bytes'.
df.rename(columns={'Size':'Size_in_bytes'},inplace=True)

# %%
#now check it 
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size_in_bytes     Installs  Type Price Content Rating  \
# 0      159     19922944.0      10,000+  Free     0       Everyone
# 1      967     14680064.0     500,000+  Free     0       Everyone
# 2    87510      9122611.2   5,000,000+  Free     0       Everyone
# 3   215644     26214400.0  50,000,000+  Free     0           Teen
# 4      967      2936012.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# >  Sometimes it may be required in other units, like in 'MBs' or 'KBs'. So from basic unit you can convert to any other unit,. or you can do it by feature engneering to add a separate column for it.
#
# - We are gonna try the very simple function of lambda,. and will put our new converted data in separate column named 'Size_in_MB' at last.
# - The calculation of lambda function is very simple.To convert  bigger unit 'MB' into the smaller unit 'bytes' we divide it twice by 1024. this is called feature engneering.  See the code below and Enjoy

# %%
#how to make it size in MB and making new column
df['Size_in_MB']=df['Size_in_bytes'].apply(lambda x: x/(1024*1024))

# %%
#now check it 
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size_in_bytes     Installs  Type Price Content Rating  \
# 0      159     19922944.0      10,000+  Free     0       Everyone
# 1      967     14680064.0     500,000+  Free     0       Everyone
# 2    87510      9122611.2   5,000,000+  Free     0       Everyone
# 3   215644     26214400.0  50,000,000+  Free     0           Teen
# 4      967      2936012.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# >  So you see, an extra column been inserted at the end of the datasets. This column shows the size of App in 'MBs', similarly you can do it for inserting a new column with size in 'KBs'. to convert into 'KBs' unit we will divide the 'MBs' unit by 1024. Enjoy the code below.

# %%
#convert into kbs unit and add the column at the end of the dataset.
df['Size_in_kb']=df['Size_in_bytes'].apply(lambda x: x/(1024))

# %%
#check new col of size in kb
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size_in_bytes     Installs  Type Price Content Rating  \
# 0      159     19922944.0      10,000+  Free     0       Everyone
# 1      967     14680064.0     500,000+  Free     0       Everyone
# 2    87510      9122611.2   5,000,000+  Free     0       Everyone
# 3   215644     26214400.0  50,000,000+  Free     0           Teen
# 4      967      2936012.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# > # **MILESTONE I COMPLETED** :   You see we are all done with size column,
# >  Till now we have learnt and practice the following important Tasks.
# > 1. There is no missing values in size column.
# > 2. We have removed `M` , `K`  from the values.
# > 3. We have converted it into numeric datatype.
# > 4. Size column have no longer different entries in it. Now its all in one single unit.
# > 5. Size column is ready to visualize graphically.
# > 6. We have converted the size in 'Bytes' , 'MBs' and 'KBs' for our convinient throug feature Engneering, we learnt practically what is feature engneering.
# > 7. We also learnt How to define a function for our need, and to apply it on a specific data.
# > 8. We learnt lambda function practically.
# > 9. `varies with devices` was a string data type , so we intentionaly converted it into null values.which we will fill later on.

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> 3.1: Working with 'Install' Column</strong></p>

# %%
#checking for unique values and vlaue counts and missing values
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# You notice above there is `'+'` symbol with each value , it simply mean 'more than that' value for example '10+' means more than 10. Due to this sign our python categorize it as 'object' and not 'integer' or 'float'. So we need to remove this '+'sign from it.

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             908
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: count, dtype: int64

# %%
df['Installs'].value_counts().sum()
# Out:
# 10841

# %%
# find how many values has '+' in it
df['Installs'].loc[df['Installs'].str.contains('\+')].value_counts().sum()
# Out:
# 10840

# %%
#see for missing values
df['Installs'].isnull().sum()
# Out:
# 0

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# There is no missing values , total values in `install` column are `10841`.
# Only problem is to remove `'+'` sign and comma , and convert the column into an 'int'
#
# - because it is discreet value not continue like size of app.
# - So lets try lambda function and tell python to replace '+' sign form our 'install' column.
#
# But How ???????????????????????????
#
# lets see the code below and everything is explained in comments with it. Hope you enjoy it.

# %%
#remove the + and comma,
#so we need to tell the computer if there is + sign replace it with a single free sapce ''.
#otherwise if it is only a number like zero only.
#then make no changes and just print as it is. (else x means that)
df['Installs']=df['Installs'].apply(lambda x: x.replace('+','') if '+'in str(x) else x)

#lets remove the commas now
#We tell python to look into column, locate the comma , change it into a free space ''. otherwise leave it as it is.
df['Installs']=df['Installs'].apply(lambda x: x.replace(',','') if ','in str(x) else x)

# convert the install column to numeric (integers because this is the number of installs/count)
df['Installs'] = df['Installs'].apply(lambda x: int(x))

# %% [markdown]
# - Let's verify if the dtypes has been changes and the `+` and `,` sign has been removed

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size_in_bytes  Installs  Type Price Content Rating  \
# 0      159     19922944.0     10000  Free     0       Everyone
# 1      967     14680064.0    500000  Free     0       Everyone
# 2    87510      9122611.2   5000000  Free     0       Everyone
# 3   215644     26214400.0  50000000  Free     0           Teen
# 4      967      2936012.8    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
#this will show the datatype of the 'install' colum
df['Installs'].dtypes
# Out:
# dtype('int64')

# %%
#lets check install col
df['Installs'].value_counts()  #all the plus signs  are removed
# Out:
# Installs
# 1000000       1579
# 10000000      1252
# 100000        1169
# 10000         1054
# 1000           908
# 5000000        752
# 100            719
# 500000         539
# 50000          479
# 5000           477
# 100000000      409
# 10             386
# 500            330
# 50000000       289
# 50             205
# 5               82
# 500000000       72
# 1               67
# 1000000000      58
# 0               15
# Name: count, dtype: int64

# %% [markdown]
# >***RESULTS*** : Waooo amazing , this is the power of python. With just one line of code all the '+' signs are been removed succefully. Enjoy ahead...

# %% [markdown]
# >***RESULTS*** :Installs Column been converted into `int64` So everything is just crystal clear, now there is no barrier to convert it into 'int'. lets do it.
#
# Waooo Lambda , you beauty

# %%
#if it is not in 'int64' convert it by using this:
df['Installs']=df['Installs'].apply(lambda x: int(x))

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1000000       1579
# 10000000      1252
# 100000        1169
# 10000         1054
# 1000           908
# 5000000        752
# 100            719
# 500000         539
# 50000          479
# 5000           477
# 100000000      409
# 10             386
# 500            330
# 50000000       289
# 50             205
# 5               82
# 500000000       72
# 1               67
# 1000000000      58
# 0               15
# Name: count, dtype: int64

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> 3.2: Binning </strong></p>
# We can generate a new column based on the installation values, which will be helpful in our analysis

# %%
df['Installs'].max() # this will show the value counts of the column
# Out:
# 1000000000

# %%
# making a new column called 'Installs_category' which will have the category of the installs
bins = [-1, 0, 10, 1000, 10000, 100000, 1000000, 10000000, 10000000000]
labels=['Zero Installs', 'Very low', 'Low', 'Moderate', 'More than moderate', 'High', 'Very High', 'Top Notch']
df['Installs_category'] = pd.cut(df['Installs'], bins=bins, labels=labels)

# %%
df['Installs_category'].value_counts() # check the value counts of the new column
# Out:
# Installs_category
# Low                   2162
# High                  2118
# Very High             2004
# More than moderate    1648
# Moderate              1531
# Top Notch              828
# Very low               535
# Zero Installs           15
# Name: count, dtype: int64

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> 3.3: Lets Deal with 'Price' Column</strong></p>

# %%
#lets see the unique value in price column
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %% [markdown]
# >***RESULTS*** :Since its price which is shown in currency that's why We see dollar sign with Each number in this column.

# %%
df['Price'].isnull().sum()
# Out:
# 0

# %% [markdown]
# - No Null Values

# %%
#checking the vlaue counts of 'Price' Column.
df['Price'].value_counts()
# Out:
# Price
# 0          10041
# $0.99        148
# $2.99        129
# $1.99         73
# $4.99         72
# $3.99         63
# $1.49         46
# $5.99         30
# $2.49         26
# $9.99         21
# $6.99         13
# $399.99       12
# $14.99        11
# $4.49          9
# $29.99         7
# $24.99         7
# $3.49          7
# $7.99          7
# $5.49          6
# $19.99         6
# $11.99         5
# $6.49          5
# $12.99         5
# $8.99          5
# $10.00         3
# $16.99         3
# $1.00          3
# $2.00          3
# $13.99         2
# $8.49          2
# $17.99         2
# $1.70          2
# $3.95          2
# $79.99         2
# $7.49          2
# $9.00          2
# $10.99         2
# $39.99         2
# $33.99         2
# $1.96          1
# $19.40         1
# $4.80          1
# $3.28          1
# $4.59          1
# $15.46         1
# $3.04          1
# $4.29          1
# $2.60          1
# $2.59          1
# $3.90          1
# $154.99        1
# $4.60          1
# ...

# %%
    # count the values having $ in the 'Price' column
df['Price'].loc[df['Price'].str.contains('\$')].value_counts().sum()
#if we put backword slash with $ it will find only $ sign value
# Out:
# 800

# %%
# This code counts the number of values in the 'Price' column which contains 0 but does not contain $ sign
df['Price'].loc[(df['Price'].str.contains('0')) & (~df['Price'].str.contains('\$'))].value_counts().sum()
# Out:
# 10041

# %% [markdown]
# - Now we can confirm that the only currency used is `$` in the `Price` column or 0 value, as `800+10041=10841 Total values`
# - The only problem is $ sign let's remove it and convert the column into numeric data type.

# %%
# remove the dollar sign from the price column and convert it to numeric
df['Price'] = df['Price'].apply(lambda x: x.replace('$', '') if '$' in str(x) else x)
# convert the price column to numeric (float because this is the price)
df['Price'] = df['Price'].apply(lambda x: float(x))

# %%
df['Price'].dtype # this will show the data type of the column
# Out:
# dtype('float64')

# %%
#using f stirng print min, max and average prices of the app
print(f'the minimum price is {df['Price'].min()}')
print(f'Max price is {df['Price'].max()}')
print(f'Average price value is {df['Price'].mean()}')
# Out:
# the minimum price is 0.0
#
# Max price is 400.0
#
# Average price value is 1.0272733142699015

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> 3.4: Descriptive Statistics</strong></p>

# %%
df.describe()
# Out:
#             Rating       Reviews  Size_in_bytes      Installs         Price  \
# count  9367.000000  1.084100e+04   9.146000e+03  1.084100e+04  10841.000000
# mean      4.191513  4.441119e+05   2.255921e+07  1.546291e+07      1.027273
# std       0.515735  2.927629e+06   2.368595e+07  8.502557e+07     15.948971
# min       1.000000  0.000000e+00   8.704000e+03  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01   5.138022e+06  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03   1.363149e+07  1.000000e+05      0.000000
# 75%       4.500000  5.476800e+04   3.145728e+07  5.000000e+06      0.000000
# max       5.000000  7.815831e+07   1.048576e+08  1.000000e+09    400.000000
#
#         Size_in_MB     Size_in_kb
# count  9146.000000    9146.000000
# mean     21.514141   22030.480308
# std      22.588679   23130.807322
# min       0.008301       8.500000
# 25%       4.900000    5017.600000
# 50%      13.000000   13312.000000
# 75%      30.000000   30720.000000
# ...

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# ---
# - Now we have `7` numerical columns, Which comes from `data cleaning` and `featrue engneering`.
# - We can observe their descriptive statistics. and make tons of observations as per our hypotheses.
# - We can see that the `Rating` column has a minimum value of `1` and a maximum value of `5`, which is the range of rating, and the mean is `4.19` which is a good rating. On an average people give this rating.
# - We can see that the `Reviews` column has a minimum value of `0` and a maximum value of `78,158,306` 78+ Millions, which is the range of reviews, and the mean is `444,111.93` which is a good number of reviews. On an average people give this number of reviews to the apps. But it does not make sense to us, as we have different categories of apps.
# - Similarly, we can observe the other columns as well.
#
# - Therefore, the most important thing is to classify as app based on the correlation matrix and then observe the descriptive statistics of the app category and number of installs, reviews, ratings, etc.
# ---
# but even before we have to think about the missing values in the dataset.

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> 3.5: Missing Values</strong></p>
# - Dealing with the missing values is one of the most important part of the data wrangling process, we must deal with the missing values in order to get the correct insights from the data.

# %%
df.isnull().sum() # this will show the number of null values in each column
# Out:
# App                     0
# Category                1
# Rating               1474
# Reviews                 0
# Size_in_bytes        1695
# Installs                0
# Type                    1
# Price                   0
# Content Rating          0
# Genres                  1
# Last Updated            0
# Current Ver             8
# Android Ver             2
# Size_in_MB           1695
# Size_in_kb           1695
# Installs_category       0
# dtype: int64

# %%
#finding missing values in whole dataframe
df.isnull().sum().sort_values(ascending=False)  #will come in order
# Out:
# Size_in_bytes        1695
# Size_in_MB           1695
# Size_in_kb           1695
# Rating               1474
# Current Ver             8
# Android Ver             2
# Category                1
# Type                    1
# Genres                  1
# App                     0
# Reviews                 0
# Installs                0
# Price                   0
# Content Rating          0
# Last Updated            0
# Installs_category       0
# dtype: int64

# %%
#find missing value percentage in data
missing_percentage=(df.isnull().sum().sort_values(ascending=False)/len(df))*100
missing_percentage
# Out:
# Size_in_bytes        15.635089
# Size_in_MB           15.635089
# Size_in_kb           15.635089
# Rating               13.596532
# Current Ver           0.073794
# Android Ver           0.018448
# Category              0.009224
# Type                  0.009224
# Genres                0.009224
# App                   0.000000
# Reviews               0.000000
# Installs              0.000000
# Price                 0.000000
# Content Rating        0.000000
# Last Updated          0.000000
# Installs_category     0.000000
# dtype: float64

# %%
#finding total number of missing values in the dataframe
df.isnull().sum().sum()
# Out:
# 6572

# %%
#plot missing values in heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#plot the missing values
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# > - - There is another way, let's plot the missing values by percentage

# %%
# make figure size
plt.figure(figsize=(16, 6))
# plot the null values by their percentage in each column
missing_percentage = df.isnull().sum()/len(df)*100
missing_percentage.plot(kind='bar')
# add the labels
plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.title('Percentage of Missing Values in each Column')
# Out:
# Text(0.5, 1.0, 'Percentage of Missing Values in each Column')

# %% [markdown]
# >- Let's plot the missing values other than 'Rating', 'Size_in_bytes' and 'Size_in_Mb' column
# >- We have missing percentage columns other than rating having less than one percent of missing values, we will plot them as follows:

# %%
plt.figure(figsize=(16, 6)) # make figure size
missing_percentage[missing_percentage < 1].plot(kind='bar') # plot the null values by their percentage in each column
plt.xlabel('Columns') # add the x-axis labels
plt.ylabel('Percentage') # add the labels for y-axis
plt.title('Percentage of Missing Values in each Column without Rating column')  # add the title for the plot
# Out:
# Text(0.5, 1.0, 'Percentage of Missing Values in each Column without Rating column')

# %%
df.isnull().sum().sort_values(ascending=False) # this will show the number of null values in each column in descending order
# Out:
# Size_in_bytes        1695
# Size_in_MB           1695
# Size_in_kb           1695
# Rating               1474
# Current Ver             8
# Android Ver             2
# Category                1
# Type                    1
# Genres                  1
# App                     0
# Reviews                 0
# Installs                0
# Price                   0
# Content Rating          0
# Last Updated            0
# Installs_category       0
# dtype: int64

# %%
(df.isnull().sum() / len(df) * 100).sort_values(ascending=False) # this will show the percentage of null values in each column
# Out:
# Size_in_bytes        15.635089
# Size_in_MB           15.635089
# Size_in_kb           15.635089
# Rating               13.596532
# Current Ver           0.073794
# Android Ver           0.018448
# Category              0.009224
# Type                  0.009224
# Genres                0.009224
# App                   0.000000
# Reviews               0.000000
# Installs              0.000000
# Price                 0.000000
# Content Rating        0.000000
# Last Updated          0.000000
# Installs_category     0.000000
# dtype: float64

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# ---
# - We have 1695 missing values in the `'Size_in_bytes'` and `'Size_in_Mb'` columns, which is 15.6% of the total values in the column.
# - We have 1474 missing values in the `'Rating'` column, which is 13.6% of the total values in the column.
# - We have 8 missing value in the `'Current Ver'` column, which is 0.07% of the total values in the column.
# - We have 2 missing values in the `'Android Ver'` column, which is 0.01% of the total values in the column.
# - We have only 1 missing value in `Category`, `Type` and `Genres` columns, which is 0.009% of the total values in the column.
#
# - We can not impute the `Rating` column as is is directly linked with the installation column. To test this Hypothesis we need to plot the `Rating` column with the `Installs` and `Size` columns and statistically test it using `pearson correlation test`.

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> 4.0: Correlation </strong></p>

# %%
df.describe() # these are numeric columns
# Out:
#             Rating       Reviews  Size_in_bytes      Installs         Price  \
# count  9367.000000  1.084100e+04   9.146000e+03  1.084100e+04  10841.000000
# mean      4.191513  4.441119e+05   2.255921e+07  1.546291e+07      1.027273
# std       0.515735  2.927629e+06   2.368595e+07  8.502557e+07     15.948971
# min       1.000000  0.000000e+00   8.704000e+03  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01   5.138022e+06  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03   1.363149e+07  1.000000e+05      0.000000
# 75%       4.500000  5.476800e+04   3.145728e+07  5.000000e+06      0.000000
# max       5.000000  7.815831e+07   1.048576e+08  1.000000e+09    400.000000
#
#         Size_in_MB     Size_in_kb
# count  9146.000000    9146.000000
# mean     21.514141   22030.480308
# std      22.588679   23130.807322
# min       0.008301       8.500000
# 25%       4.900000    5017.600000
# 50%      13.000000   13312.000000
# 75%      30.000000   30720.000000
# ...

# %%
# Make a correlation matrix of numeric columns
plt.figure(figsize=(16, 10)) # make figure size  
numeric_cols = ['Rating', 'Reviews', 'Size_in_bytes', 'Installs', 'Price', 'Size_in_MB'] # make a list of numeric columns
sns.heatmap(df[numeric_cols].corr(), annot=True) # plot the correlation matrix
# Out:
# <Axes: >

# %%
# we can also calculate the correlation matrix using pandas
df[numeric_cols].corr() # this will show the correlation matrix
# Out:
#                  Rating   Reviews  Size_in_bytes  Installs     Price  \
# Rating         1.000000  0.068147       0.084098  0.051393 -0.021851
# Reviews        0.068147  1.000000       0.238218  0.643123 -0.009666
# Size_in_bytes  0.084098  0.238218       1.000000  0.164794 -0.023000
# Installs       0.051393  0.643123       0.164794  1.000000 -0.011688
# Price         -0.021851 -0.009666      -0.023000 -0.011688  1.000000
# Size_in_MB     0.084098  0.238218       1.000000  0.164794 -0.023000
#
#                Size_in_MB
# Rating           0.084098
# Reviews          0.238218
# Size_in_bytes    1.000000
# Installs         0.164794
# Price           -0.023000
# Size_in_MB       1.000000

# %%
# we can calculate the pearson correlation coefficient using scipy as well as follows

# this is to install scipy if you have not done it before
# pip install scipy 
from scipy import stats

# remove rows containing NaN or infinite values (Important to calculate Pearson's R)
df_clean = df.dropna()

# calculate Pearson's R between Rating and Installs
pearson_r, _ = stats.pearsonr(df_clean['Reviews'], df_clean['Installs'])
print(f"Pearson's R between Reviews and Installs: {pearson_r:.4f}")
# Out:
# Pearson's R between Reviews and Installs: 0.6262

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# - Lighter color shows the high correlation and darker color shows the low correlation
# - We can see that the `Reviews` column has a high correlation with the `Installs` column, which is `0.64` according to corr(). Which is quite good.
#   - This shows that the more the reviews the more the installs are for one app. If in any case we need to impute reviews we have to think of number of install.
#     - If we have an app with `2` installs and we impute the reviews with `1000` or via average reviews then it will be wrong.
# - Installs is slightly correlated with `Size_in_Mb` or `Size_in_bytes` , which is `0.16`, this also shows us the importance of size and Installs. But we can not depend on it as the Peason correlation is very low.

# %% [markdown]
# - Before going ahead, let's remove the rows with missing values in the `Current Ver`, `Android Ver`, `Category`, `Type` and `Genres` columns, as they are very less in number and will not affect our analysis.

# %%
# length before removing null values
print(f"Length of the dataframe before removing null values: {len(df)}")
# Out:
# Length of the dataframe before removing null values: 10841

# %%
# remove the rows having null values in the 'Current Ver', 'Android Ver', 'Category', 'Type' and 'Genres' column
df.dropna(subset=['Current Ver', 'Android Ver', 'Category', 'Type', 'Genres'], inplace=True)

# %%
# length after removing null values
print(f"Length of the dataframe after removing null values: {len(df)}")
# Out:
# Length of the dataframe after removing null values: 10829

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# - We have removed `12` rows having null values in the `Current Ver`, `Android Ver`, `Category`, `Type` and `Genres` columns.

# %%
# let's check the null values again
df.isnull().sum().sort_values(ascending=False)
# Out:
# Size_in_bytes        1694
# Size_in_MB           1694
# Size_in_kb           1694
# Rating               1469
# App                     0
# Category                0
# Reviews                 0
# Installs                0
# Type                    0
# Price                   0
# Content Rating          0
# Genres                  0
# Last Updated            0
# Current Ver             0
# Android Ver             0
# Installs_category       0
# dtype: int64

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# - Only `Rating` and `Size_in_bytes` or `Size_in_Mb` columns are left with missing values.
#   - We know that we have to be carefull while deadling with `Rating` column, as it is directly linked with the `Installs` column.
#   - In Size columns we already know about `Varies with device` values, which we have converted into null values, we do not need to impute at the moment, as every app has different size and nobody can predict that as nearly as possible.
# ---

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_in_bytes', 'Installs',
#        'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver', 'Size_in_MB', 'Size_in_kb',
#        'Installs_category'],
#       dtype='object')

# %%
# use groupby function to find the trend of Rating in each Installs_category
df.groupby('Installs_category')['Rating'].describe()
# Out:
#                      count      mean       std  min  25%  50%  75%  max
# Installs_category
# Zero Installs          0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# Very low              81.0  4.637037  0.845199  1.0  4.8  5.0  5.0  5.0
# Low                 1278.0  4.170970  0.825605  1.0  3.8  4.4  4.8  5.0
# Moderate            1440.0  4.035417  0.604428  1.4  3.8  4.2  4.5  5.0
# More than moderate  1616.0  4.093255  0.505619  1.6  3.9  4.2  4.5  4.9
# High                2113.0  4.207525  0.376594  1.8  4.0  4.3  4.5  4.9
# Very High           2004.0  4.287076  0.294902  2.0  4.1  4.3  4.5  4.9
# Top Notch            828.0  4.374396  0.193726  3.1  4.3  4.4  4.5  4.8

# %%
print('The number of total rows in this data set is',df.shape[0])
print('The missing values in Rating column are', df['Rating'].isnull().sum())
# Out:
# The number of total rows in this data set is 10829
#
# The missing values in Rating column are 1469

# %%
df['Rating'].isnull().sum()
# Out:
# 1469

# %% [markdown]
# >There are sill 1469 missing values in `Ratings` column.

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> 4.1 Replace Missing Value of 'Rating' With average Rating in Each 'Install Category'</strong></p>

# %%
# Step 1: Calculate the average rating for each 'Installs_category'
mean_ratings = df.groupby('Installs_category')['Rating'].mean()

# Step 2: Replace the missing values in the 'Rating' column
for index, row in df.iterrows():
    if pd.isnull(row['Rating']):
        installs_category = row['Installs_category']
        mean_rating = mean_ratings[installs_category]
        df.loc[index, 'Rating'] = mean_rating

# %%
df.isnull().sum()   #here we see that in Rating columns 14 values are null.
# Out:
# App                     0
# Category                0
# Rating                 14
# Reviews                 0
# Size_in_bytes        1694
# Installs                0
# Type                    0
# Price                   0
# Content Rating          0
# Genres                  0
# Last Updated            0
# Current Ver             0
# Android Ver             0
# Size_in_MB           1694
# Size_in_kb           1694
# Installs_category       0
# dtype: int64

# %%
df['Rating'].isnull().sum()  #total 1474 values ar null
# Out:
# 14

# %%
# in which Install_category the Rating has NaN values
df['Installs_category'].loc[df['Rating'].isnull()].value_counts()
# Out:
# Installs_category
# Zero Installs         14
# Very low               0
# Low                    0
# Moderate               0
# More than moderate     0
# High                   0
# Very High              0
# Top Notch              0
# Name: count, dtype: int64

# %% [markdown]
# >-  Let's plot this and have a look

# %%
# plot the boxplot of Rating in each Installs_category
plt.figure(figsize=(16, 6)) # make figure size
sns.boxplot(x='Installs_category', y='Rating', hue='Installs_category', data=df) # plot the boxplot

# add the text of number of null values in each category
plt.text(0, 3.5, 'Null values: 14')
plt.text(1, 3.5, 'Null values: 874')
plt.text(2, 3.5, 'Null values: 86')
plt.text(3, 3.5, 'Null values: 31')
plt.text(4, 3.5, 'Null values: 3')
plt.text(5, 3.5, 'Null values: 0')
plt.text(6, 3.5, 'Null values: 0')
plt.text(7, 3.5, 'Null values: 0')
# Out:
# Text(7, 3.5, 'Null values: 0')

# %% [markdown]
# >- Let's check if there is any similar link with Reviews as well

# %%
# in which Install_category the Rating has NaN values
df['Installs_category'].loc[df['Reviews'].isnull()].value_counts()
# Out:
# Installs_category
# Zero Installs         0
# Very low              0
# Low                   0
# Moderate              0
# More than moderate    0
# High                  0
# Very High             0
# Top Notch             0
# Name: count, dtype: int64

# %% [markdown]
# >- There are no Null values in Reviews

# %%
# let's plot the same plots for Reviews column as well
plt.figure(figsize=(16, 6)) # make figure size
sns.boxplot(x='Installs_category', y= 'Reviews', data=df) # plot the boxplot
# Out:
# <Axes: xlabel='Installs_category', ylabel='Reviews'>

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# - The data looks really imbalance, let's normalize the data using log transformation

# %%
# let's plot the same plots for Reviews column as well
plt.figure(figsize=(16, 6)) # make figure size
sns.boxplot(x='Installs_category', y= np.log10(df['Reviews']), data=df) # plot the boxplot
# Out:
# <Axes: xlabel='Installs_category', ylabel='Reviews'>

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# - We also draw the scatter plot of the `Rating` and `Review` columns with the `Installs` column

# %%
# Draw a scatter plot between Rating, Reviews and Installs
plt.figure(figsize=(16, 6)) # make figure size
sns.scatterplot(x='Rating', y='Reviews', hue='Installs_category', data=df) # plot the scatter plot
# Out:
# <Axes: xlabel='Rating', ylabel='Reviews'>

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# - It doesn't show any trend, because, you should know that Rating is a categorical variable (Ordinal) and Reviews is a continuous variable, therefore, we can not plot them together.
# - Let's try with Reviews and Installs

# %%
# plot reviews and installs in a scatter plot
plt.figure(figsize=(16, 6)) # make figure size
sns.scatterplot(x='Reviews', y='Installs', data=df) # plot the scatter plot
# Out:
# <Axes: xlabel='Reviews', ylabel='Installs'>

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# - We did not see any trend and the issue is we need to normalize the data before plotting it, let's try with log transformation

# %%
# plot reviews and installs in a scatter plot
plt.figure(figsize=(16, 6)) # make figure size
sns.scatterplot(x=np.log10(df['Reviews']), y=np.log10(df['Installs']), data=df) # plot the scatter plot
# Out:
# <Axes: xlabel='Reviews', ylabel='Installs'>

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# - Now we see a slight trend but still the issue is installs were given in a factorial manner, as 10+, 20+, 1000+ etc, and these are not continuous number but Discreet one, therefore, we can only see a slight trends here. Let's plot a line plot to see the trend.

# %%
# plot reviews and installs in a scatter plot with trend line
plt.figure(figsize=(16, 6)) # make figure size
sns.lmplot(x='Reviews', y='Installs', data=df) # plot the scatter plot with trend line

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# - Here, we can see a nice trend, which shows that number of Reviews increases with the number of Installs, which is quite obvious.
# - -We can see that most of the null values from `Rating` column are no - Moderate Installation apps, which make sense that if the app has less installations, it has less Rating and review.
# - ---

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> 4.2: Duplicate Values</strong></p>
#
# * Removing duplicates is one of the most important part of the data wrangling process, we must remove the duplicates in order to get the correct insights from the data.
# * If you do not remove duplicates from a dataset, it can lead to incorrect insights and analysis.
# * Duplicates can skew statistical measures such as mean, median, and standard deviation, and can also lead to over-representation of certain data points.
# * It is important to remove duplicates to ensure the accuracy and reliability of your data analysis.

# %%
# find duplicate if any
df.duplicated().sum()
# Out:
# 483

# %% [markdown]
# > This shows us total duplicates, but we can also check based on the app name, as we know that every app has a unique name.

# %%
# find duplicate if any in the 'App' column
df['App'].duplicated().sum()
# Out:
# 1181

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# - Oops! we have 1181 dupicate app names
# - Can we find a column which can help us to remove the duplicates?
#
# let's check for number of duplicates in each column using a for loop and printing the output

# %%
# let's check for number of duplicates
for col in df.columns:
    print(f"Number of duplicates in {col} column are: {df[col].duplicated().sum()}")
# Out:
# Number of duplicates in App column are: 1181
#
# Number of duplicates in Category column are: 10796
#
# Number of duplicates in Rating column are: 10784
#
# Number of duplicates in Reviews column are: 4830
#
# Number of duplicates in Size_in_bytes column are: 10373
#
# Number of duplicates in Installs column are: 10809
#
# Number of duplicates in Type column are: 10827
#
# Number of duplicates in Price column are: 10737
#
# Number of duplicates in Content Rating column are: 10823
#
# Number of duplicates in Genres column are: 10710
#
# Number of duplicates in Last Updated column are: 9453
#
# Number of duplicates in Current Ver column are: 7998
#
# Number of duplicates in Android Ver column are: 10796
#
# Number of duplicates in Size_in_MB column are: 10373
#
# Number of duplicates in Size_in_kb column are: 10373
#
# Number of duplicates in Installs_category column are: 10821

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# This means that the only better way to find duplicates is to check for whole data

# %%
# print the number of duplicates in df
print(f"Number of duplicates in df are: {df.duplicated().sum()}")
# Out:
# Number of duplicates in df are: 483

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> 4.3: Find and Watch All Duplicate if they are Real</strong></p>

# %%
# # find exact duplicates and print them
df[df['App'].duplicated(keep=False)].sort_values(by='App').head(5)
# Out:
#                              App            Category  Rating  Reviews  \
# 1393       10 Best Foods for You  HEALTH_AND_FITNESS     4.0     2490
# 1407       10 Best Foods for You  HEALTH_AND_FITNESS     4.0     2490
# 2543  1800 Contacts - Lens Store             MEDICAL     4.7    23160
# 2322  1800 Contacts - Lens Store             MEDICAL     4.7    23160
# 2385  2017 EMRA Antibiotic Guide             MEDICAL     4.4       12
#
#       Size_in_bytes  Installs  Type  Price Content Rating            Genres  \
# 1393      3984588.8    500000  Free   0.00   Everyone 10+  Health & Fitness
# 1407      3984588.8    500000  Free   0.00   Everyone 10+  Health & Fitness
# 2543     27262976.0   1000000  Free   0.00       Everyone           Medical
# 2322     27262976.0   1000000  Free   0.00       Everyone           Medical
# 2385      3984588.8      1000  Paid  16.99       Everyone           Medical
#
#            Last Updated Current Ver   Android Ver  Size_in_MB  Size_in_kb  \
# ...

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> 4.4: Remove Duplicate</strong></p>

# %%
# remove the duplicates
df.drop_duplicates(inplace=True)

# %%
# print the number of rows and columns after removing duplicates
print(f"Number of rows after removing duplicates: {df.shape[0]}")
# Out:
# Number of rows after removing duplicates: 10346

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#050505 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#F9DD9C ; border-radius: 5px 5px;"><strong> OBSERVATIONS</strong></p>
# >  Now we have removed 483 duplicates from the dataset. and have 10346 rows left.
#
# ---

# %% [markdown]
# # checking the normality of our data

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_in_bytes', 'Installs',
#        'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver', 'Size_in_MB', 'Size_in_kb',
#        'Installs_category'],
#       dtype='object')

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> 4.5: Usefull Insights from Data</strong></p>

# %% [markdown]
# ># Q.1 : What are the top 10 categories with the highest number of apps?

# %%
# which category has highest number of apps
df['Category'].value_counts().head(10) # this will show the top 10 categories with highest number of apps
# Out:
# Category
# FAMILY             1939
# GAME               1121
# TOOLS               841
# BUSINESS            427
# MEDICAL             408
# PRODUCTIVITY        407
# PERSONALIZATION     386
# LIFESTYLE           373
# COMMUNICATION       366
# FINANCE             360
# Name: count, dtype: int64

# %% [markdown]
# > # Q.2 What are the top 10 categories with highest number of installs?

# %%
# category with highest number of Installs
df.groupby('Category')['Installs'].sum().sort_values(ascending=False).head(10)
# Out:
# Category
# GAME                  31544024415
# COMMUNICATION         24152276251
# SOCIAL                12513867902
# PRODUCTIVITY          12463091369
# TOOLS                 11452271905
# FAMILY                10041632405
# PHOTOGRAPHY            9721247655
# TRAVEL_AND_LOCAL       6361887146
# VIDEO_PLAYERS          6222002720
# NEWS_AND_MAGAZINES     5393217760
# Name: Installs, dtype: int64

# %% [markdown]
# > # Q. 3 What are top 10 categories with  highest number of reviews?

# %%
# Category with highest number of Reviews
df.groupby('Category')['Reviews'].sum().sort_values(ascending=False).head(10)
# Out:
# Category
# GAME               1415536650
# COMMUNICATION       601273552
# SOCIAL              533576829
# FAMILY              396771746
# TOOLS               273181033
# PHOTOGRAPHY         204297410
# VIDEO_PLAYERS       110380188
# PRODUCTIVITY        102554498
# SHOPPING             94931162
# PERSONALIZATION      75192744
# Name: Reviews, dtype: int64

# %% [markdown]
# > # Q. 4 What is the average rating for an App on Google Play?

# %%
print('The Average Rating for an App is',df['Rating'].mean())
# Out:
# The Average Rating for an App is 4.204619441017959

# %% [markdown]
# > # Q. 5 What are the top 10 Category of Apps with highest Rating=5 on Google Play ?

# %%
# Filter apps with a rating of 5
top_rated_apps = df[df['Rating'] == 5]

#  Count the number of 5-star apps in each category
category_counts = top_rated_apps['Category'].value_counts()
category_counts.head(10)
# Out:
# Category
# FAMILY                67
# LIFESTYLE             29
# MEDICAL               25
# BUSINESS              18
# TOOLS                 17
# GAME                  12
# HEALTH_AND_FITNESS    12
# PERSONALIZATION       10
# SOCIAL                 8
# PRODUCTIVITY           8
# Name: count, dtype: int64

# %% [markdown]
# > # Q. 6 What are the top 10 Category of Apps with Least Rating=1 on Google Play ?

# %%
# Filter apps with a rating of 1
least_rated_apps = df[df['Rating'] == 1]
least_rated_apps

# #  Count the number of least rated apps in each category
category_counts = pd.DataFrame(least_rated_apps['Category'].value_counts())
category_counts
# Out:
#                count
# Category
# FAMILY             3
# MEDICAL            3
# TOOLS              3
# FINANCE            2
# DATING             1
# GAME               1
# PRODUCTIVITY       1
# COMMUNICATION      1
# BUSINESS           1

# %% [markdown]
# > # Q. 7 What is the average size of an App on google play store ?

# %%
print('The average size of an App on Google Play is ',df['Size_in_MB'].mean())
# Out:
# The average size of an App on Google Play is  21.306240091560618

# %%
df.describe()
# Out:
#              Rating       Reviews  Size_in_bytes      Installs         Price  \
# count  10332.000000  1.034600e+04   8.821000e+03  1.034600e+04  10346.000000
# mean       4.204619  4.063338e+05   2.234121e+07  1.417266e+07      1.031561
# std        0.493478  2.698179e+06   2.364101e+07  8.028090e+07     16.287252
# min        1.000000  0.000000e+00   8.704000e+03  0.000000e+00      0.000000
# 25%        4.093255  3.200000e+01   4.928307e+06  1.000000e+03      0.000000
# 50%        4.300000  1.688500e+03   1.363149e+07  1.000000e+05      0.000000
# 75%        4.500000  4.659825e+04   3.040870e+07  1.000000e+06      0.000000
# max        5.000000  7.815831e+07   1.048576e+08  1.000000e+09    400.000000
#
#         Size_in_MB     Size_in_kb
# count  8821.000000    8821.000000
# mean     21.306240   21817.589854
# std      22.545826   23086.926331
# min       0.008301       8.500000
# 25%       4.700000    4812.800000
# 50%      13.000000   13312.000000
# ...

# %%
# plot the rating distribution
plt.figure(figsize=(16, 6)) # make figure size
sns.kdeplot(df['Rating'], color="blue", shade=True) # plot the distribution plot
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
# plot number of installs for free vs paid apps make a bar plot
plt.figure(figsize=(16, 6)) # make figure size
sns.barplot(x='Type', y='Installs', data=df) # plot the bar plot
plt.title('Bar plot of Free Apps vs Paid Apps')
# Out:
# Text(0.5, 1.0, 'Bar plot of Free Apps vs Paid Apps')

# %%
# show scatter plot as well where x-axis is Installs and y-axis is Price and hue is Type
plt.figure(figsize=(16, 6)) # make figure size

sns.scatterplot(x='Installs', y='Price', hue='Type', data=df) # plot the scatter plot
# Out:
# <Axes: xlabel='Installs', ylabel='Price'>

# %% [markdown]
# ## I

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> Conclusion</strong></p>
# - The analysis focused on initial data cleaning, exploration, and basic correlation analysis.
# - This report presents a preliminary analysis of a Google Play Store app dataset, providing insights for beginners in data analysis. While this analysis offers a starting point, it can be further enhanced with more advanced techniques and a deeper exploration of the data.
# - Successfully cleaned and transformed the "Size" column, converting it from a string to a numeric format.
# Identified missing values and discussed potential imputation strategies.
# - Observed basic descriptive statistics for numerical columns.
# - Explored potential correlations between features like "Rating," "Reviews," "Installs," and "Size."

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 30px; color :#F2D742 ; font-family : 'Comic Sans MS'; text-align : center; background-color :#263049 ; border-radius: 5px 5px;"><strong> Let's Connect</strong></p>
#
# If you found this analysis helpful, please consider upvoting it on Kaggle to support other learners. Your feedback and suggestions are precious to me as a beginner. I'm eager to learn from experts and improve my data analysis skills. Let's connect
